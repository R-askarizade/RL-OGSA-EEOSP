# %%
import sys
sys.path.append("D:\Papers\DCHPC\DCHPC")
from simulation import Simulation
from ConfigClass.config import plot_comparison

# %% [markdown]
# ## AREA : (500 * 500)

# %% [markdown]
# ### 100 NODES

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim = Simulation(
    area_size=(500, 500),
    n_nodes=100,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim.save_results("wsn_100_DRL_results.csv")
sim.plot()
# Out:
# [Placement] Edge nodes fine-tuned. Reward re-evaluated.
# c:\Users\razieh\anaconda3\envs\torch-pgu\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\razieh\anaconda3\envs\torch-pgu\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [Simulation] All nodes died at round 42371. Stopping early.
#
# === Simulation Summary ===
# FND: 32
# HND: 543
# LND: 42371
# TotalGenerated: 5812
# TotalDelivered: 5414
# RoundsSimulated: 42371
# Results saved to wsn_100_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim1 = Simulation(
    area_size=(500, 500),
    n_nodes=100,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim1.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim1.save_results("wsn_100_random_results.csv")
sim1.plot()
# Out:
# [Simulation] All nodes died at round 39670. Stopping early.
#
# === Simulation Summary ===
# FND: 41
# HND: 576
# LND: 39670
# TotalGenerated: 6345
# TotalDelivered: 5916
# RoundsSimulated: 39670
# Results saved to wsn_100_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim, sim1], ["Q-learning", "random"])

# %% [markdown]
# ### 150 nodes

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim2 = Simulation(
    area_size=(500, 500),
    n_nodes=150,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim2.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim2.save_results("wsn_150_DRL_results.csv")
sim2.plot()
# Out:
# [Placement] Edge nodes fine-tuned. Reward re-evaluated.
# [Simulation] All nodes died at round 25824. Stopping early.
#
# === Simulation Summary ===
# FND: 36
# HND: 528
# LND: 25824
# TotalGenerated: 8521
# TotalDelivered: 7980
# RoundsSimulated: 25824
# Results saved to wsn_150_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim3 = Simulation(
    area_size=(500, 500),
    n_nodes=150,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim3.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim3.save_results("wsn_150_random_results.csv")
sim3.plot()
# Out:
# [Simulation] All nodes died at round 36237. Stopping early.
#
# === Simulation Summary ===
# FND: 29
# HND: 662
# LND: 36237
# TotalGenerated: 9167
# TotalDelivered: 8564
# RoundsSimulated: 36237
# Results saved to wsn_150_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim2, sim3], ["Q-learning", "random"])

# %% [markdown]
# ### 200 NODES

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim4 = Simulation(
    area_size=(500, 500),
    n_nodes=200,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim4.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim4.save_results("wsn_200_DRL_results.csv")
sim4.plot()
# Out:
# [Placement] Edge nodes fine-tuned. Reward re-evaluated.
# [Simulation] All nodes died at round 32692. Stopping early.
#
# === Simulation Summary ===
# FND: 32
# HND: 546
# LND: 32692
# TotalGenerated: 11399
# TotalDelivered: 10658
# RoundsSimulated: 32692
# Results saved to wsn_200_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim5 = Simulation(
    area_size=(500, 500),
    n_nodes=200,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim5.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim5.save_results("wsn_200_random_results.csv")
sim5.plot()
# Out:
# [Simulation] All nodes died at round 35453. Stopping early.
#
# === Simulation Summary ===
# FND: 32
# HND: 668
# LND: 35453
# TotalGenerated: 12684
# TotalDelivered: 11897
# RoundsSimulated: 35453
# Results saved to wsn_200_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim4, sim5], ["Q-learning", "random"])

# %% [markdown]
# ### 300 NODES

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim6 = Simulation(
    area_size=(500, 500),
    n_nodes=300,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim6.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim6.save_results("wsn_300_DRL_results.csv")
sim6.plot()
# Out:
# [Placement] Edge nodes fine-tuned. Reward re-evaluated.
# [Simulation] All nodes died at round 16702. Stopping early.
#
# === Simulation Summary ===
# FND: 78
# HND: 556
# LND: 16702
# TotalGenerated: 16286
# TotalDelivered: 15171
# RoundsSimulated: 16702
# Results saved to wsn_300_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim7 = Simulation(
    area_size=(500, 500),
    n_nodes=300,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="adaptive",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim7.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim7.save_results("wsn_300_random_results.csv")
sim7.plot()
# Out:
# [Simulation] All nodes died at round 17235. Stopping early.
#
# === Simulation Summary ===
# FND: 103
# HND: 661
# LND: 17235
# TotalGenerated: 17900
# TotalDelivered: 16807
# RoundsSimulated: 17235
# Results saved to wsn_300_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim6, sim7], ["Q-learning", "random"])
