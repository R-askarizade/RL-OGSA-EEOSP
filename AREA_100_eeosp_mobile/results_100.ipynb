# %%
import sys
sys.path.append("D:\Papers\DCHPC\DCHPC")
from simulation import Simulation
from ConfigClass.config import plot_comparison

# %% [markdown]
# ## AREA : (100 * 100)

# %% [markdown]
# ### 100 NODES - Initial Energy: 0.5 J

# %%
sim = Simulation(
    area_size=(100, 100),
    n_nodes=100,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="eeosp",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim.save_results("wsn_100_0.5_random_results.csv")
sim.plot()
# Out:
# c:\Users\razieh\anaconda3\envs\torch-pgu\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\razieh\anaconda3\envs\torch-pgu\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [Simulation] All nodes died at round 4381. Stopping early.
#
# === Simulation Summary ===
# FND: 569
# HND: 768
# LND: 4381
# TotalGenerated: 18704
# TotalDelivered: 18043
# RoundsSimulated: 4381
# Results saved to wsn_100_0.5_random_results.csv

# %% [markdown]
# ### 100 NODES - Initial Energy : 1J

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim2 = Simulation(
    area_size=(100, 100),
    n_nodes=100,
    rounds=60000,
    init_energy=1,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="eeosp",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim2.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim2.save_results("wsn_100_1J_DRL_results.csv")
sim2.plot()
# Out:
# [Simulation] All nodes died at round 1964. Stopping early.
#
# === Simulation Summary ===
# FND: 1369
# HND: 1662
# LND: 1964
# TotalGenerated: 39064
# TotalDelivered: 36787
# RoundsSimulated: 1964
# Results saved to wsn_100_1J_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim3 = Simulation(
    area_size=(100, 100),
    n_nodes=100,
    rounds=60000,
    init_energy=0.5,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="eeosp",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim3.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim3.save_results("wsn_100_1J_random_results.csv")
sim3.plot()
# Out:
# [Simulation] All nodes died at round 4485. Stopping early.
#
# === Simulation Summary ===
# FND: 633
# HND: 799
# LND: 4485
# TotalGenerated: 19209
# TotalDelivered: 18452
# RoundsSimulated: 4485
# Results saved to wsn_100_1J_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim2, sim3], ["Q-learning", "random"])

# %% [markdown]
# ### 200 NODES - Initail Energy : 1J

# %% [markdown]
# #### Voronoi-Q-learning Positioninig for Initial Sensor Deployment

# %%
sim6 = Simulation(
    area_size=(100, 100),
    n_nodes=200,
    rounds=60000,
    init_energy=1,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="eeosp",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="DRL"
)
metrics = sim6.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim6.save_results("wsn_200_1J_DRL_results.csv")
sim6.plot()
# Out:
# [Simulation] All nodes died at round 2678. Stopping early.
#
# === Simulation Summary ===
# FND: 627
# HND: 935
# LND: 2678
# TotalGenerated: 46821
# TotalDelivered: 43995
# RoundsSimulated: 2678
# Results saved to wsn_200_1J_DRL_results.csv

# %% [markdown]
# #### Random Positioning for Initial Sensor Deployment

# %%
sim7 = Simulation(
    area_size=(100, 100),
    n_nodes=200,
    rounds=60000,
    init_energy=1,
    comm_range=50.0,
    recluster_period=50,
    sink_mode="eeosp",
    sink_visit_period=5,
    routing_mode="multi-hop",
    seed=42,
    localization_mode="random"
)
metrics = sim7.run()
print("\n=== Simulation Summary ===")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}" if isinstance(v, float) else f"{k}: {v}")

sim7.save_results("wsn_200_1J_random_results.csv")
sim7.plot()
# Out:
# [Simulation] All nodes died at round 13019. Stopping early.
#
# === Simulation Summary ===
# FND: 763
# HND: 803
# LND: 13019
# TotalGenerated: 46814
# TotalDelivered: 44840
# RoundsSimulated: 13019
# Results saved to wsn_200_1J_random_results.csv

# %% [markdown]
# #### Comparative Plot

# %%
plot_comparison([sim6, sim7], ["Q-learning", "random"])
